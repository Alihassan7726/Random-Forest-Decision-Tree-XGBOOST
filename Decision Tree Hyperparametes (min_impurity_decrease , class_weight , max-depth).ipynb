# %% [markdown]
# 1. Decision Trees can handle both numerical and categorical Data.
# 2. Requires little or no preprosessing such as normalization or dummy encoding .

# %%
import pandas as pd
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cd Downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads'
# C:\Users\Ali\Machine Learning\Decision Tree

# %%
cancer = pd.read_csv(r'C:/BEPEC Python Material/Machine Learning/Logistic Regression/KNN.csv')

# %%
del cancer['id']
cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# 1         0.1922  ...         11.88          22.94            78.28
# 2         0.1714  ...         12.41          26.44            79.93
# 3         0.1771  ...         11.92          15.77            76.53
# 4         0.1721  ...         16.20          15.73           104.50
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       549.1            0.1385             0.1266          0.12420
# 1       424.8            0.1213             0.2515          0.19160
# 2       471.4            0.1369             0.1482          0.10670
# 3       434.0            0.1367             0.1822          0.08669
# 4       819.1            0.1126             0.1737          0.13620
#
#    points_worst  symmetry_worst  dimension_worst
# 0       0.09391          0.2827          0.06771
# 1       0.07926          0.2940          0.07587
# 2       0.07431          0.2998          0.07881
# 3       0.08611          0.2102          0.06784
# 4       0.08178          0.2487          0.06766
#
# [5 rows x 31 columns]

# %%
import seaborn as sns
sns.countplot(cancer['diagnosis'])

# %%
X = cancer.iloc[:,1:]
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.32         12.39           78.85      464.1          0.10280
# 1        10.60         18.95           69.28      346.4          0.09688
# 2        11.04         16.83           70.92      373.2          0.10770
# 3        11.28         13.39           73.00      384.8          0.11640
# 4        15.19         13.21           97.65      711.8          0.07963
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           0.06981         0.03987      0.03700         0.1959
# 1           0.11470         0.06387      0.02642         0.1922
# 2           0.07804         0.03046      0.02480         0.1714
# 3           0.11360         0.04635      0.04796         0.1771
# 4           0.06934         0.03393      0.02657         0.1721
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.05955  ...         13.50          15.64            86.97
# 1         0.06491  ...         11.88          22.94            78.28
# 2         0.06340  ...         12.41          26.44            79.93
# 3         0.06072  ...         11.92          15.77            76.53
# 4         0.05544  ...         16.20          15.73           104.50
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       549.1            0.1385             0.1266          0.12420
# 1       424.8            0.1213             0.2515          0.19160
# 2       471.4            0.1369             0.1482          0.10670
# 3       434.0            0.1367             0.1822          0.08669
# 4       819.1            0.1126             0.1737          0.13620
#
#    points_worst  symmetry_worst  dimension_worst
# 0       0.09391          0.2827          0.06771
# 1       0.07926          0.2940          0.07587
# 2       0.07431          0.2998          0.07881
# 3       0.08611          0.2102          0.06784
# 4       0.08178          0.2487          0.06766
#
# [5 rows x 30 columns]

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   diagnosis          569 non-null    object
#  1   radius_mean        569 non-null    float64
#  2   texture_mean       569 non-null    float64
#  3   perimeter_mean     569 non-null    float64
#  4   area_mean          569 non-null    float64
#  5   smoothness_mean    569 non-null    float64
#  6   compactness_mean   569 non-null    float64
#  7   concavity_mean     569 non-null    float64
#  8   points_mean        569 non-null    float64
#  9   symmetry_mean      569 non-null    float64
#  10  dimension_mean     569 non-null    float64
#  11  radius_se          569 non-null    float64
#  12  texture_se         569 non-null    float64
#  13  perimeter_se       569 non-null    float64
#  14  area_se            569 non-null    float64
#  15  smoothness_se      569 non-null    float64
#  16  compactness_se     569 non-null    float64
#  17  concavity_se       569 non-null    float64
#  18  points_se          569 non-null    float64
#  19  symmetry_se        569 non-null    float64
#  20  dimension_se       569 non-null    float64
#  21  radius_worst       569 non-null    float64
#  22  texture_worst      569 non-null    float64
#  23  perimeter_worst    569 non-null    float64
#  24  area_worst         569 non-null    float64
#  25  smoothness_worst   569 non-null    float64
#  26  compactness_worst  569 non-null    float64
#  27  concavity_worst    569 non-null    float64
#  28  points_worst       569 non-null    float64
#  29  symmetry_worst     569 non-null    float64
#  30  dimension_worst    569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %%
pd.set_option('precision',1)
cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B         12.3          12.4            78.8      464.1
# 1         B         10.6          18.9            69.3      346.4
# 2         B         11.0          16.8            70.9      373.2
# 3         B         11.3          13.4            73.0      384.8
# 4         B         15.2          13.2            97.7      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          1.0e-01           7.0e-02         4.0e-02      3.7e-02
# 1          9.7e-02           1.1e-01         6.4e-02      2.6e-02
# 2          1.1e-01           7.8e-02         3.0e-02      2.5e-02
# 3          1.2e-01           1.1e-01         4.6e-02      4.8e-02
# 4          8.0e-02           6.9e-02         3.4e-02      2.7e-02
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0            0.2  ...          13.5           15.6             87.0
# 1            0.2  ...          11.9           22.9             78.3
# 2            0.2  ...          12.4           26.4             79.9
# 3            0.2  ...          11.9           15.8             76.5
# 4            0.2  ...          16.2           15.7            104.5
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       549.1               0.1                0.1          1.2e-01
# 1       424.8               0.1                0.3          1.9e-01
# 2       471.4               0.1                0.1          1.1e-01
# 3       434.0               0.1                0.2          8.7e-02
# 4       819.1               0.1                0.2          1.4e-01
#
#    points_worst  symmetry_worst  dimension_worst
# 0       9.4e-02             0.3          6.8e-02
# 1       7.9e-02             0.3          7.6e-02
# 2       7.4e-02             0.3          7.9e-02
# 3       8.6e-02             0.2          6.8e-02
# 4       8.2e-02             0.2          6.8e-02
#
# [5 rows x 31 columns]

# %%
y = cancer.iloc[:,:1]
y.head()
# Out:
#   diagnosis
# 0         B
# 1         B
# 2         B
# 3         B
# 4         B

# %% [markdown]
# # Simple Decision Tree

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_train,X_test ,y_train,y_test = train_test_split(X,y, test_size = 0.2 , random_state = 0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (455, 1)
# (114, 30)
# (114, 1)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
train_expected = y_train
test_expected = y_test
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# %%
#Confusion Matrix
print(metrics.confusion_matrix(test_expected, test_pred),"\n-------------------------------")
print(metrics.confusion_matrix(train_expected, train_pred))
# Out:
# [[73  4]
#  [ 6 31]]
# -------------------------------
# [[280   0]
#  [  0 175]]

# %%
print(y_train['diagnosis'].value_counts())
print(y_test['diagnosis'].value_counts())
# Out:
# B    280
# M    175
# Name: diagnosis, dtype: int64
# B    77
# M    37
# Name: diagnosis, dtype: int64

# %%
print(metrics.classification_report(test_expected, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.92      0.95      0.94        77
#            M       0.89      0.84      0.86        37
#
#     accuracy                           0.91       114
#    macro avg       0.90      0.89      0.90       114
# weighted avg       0.91      0.91      0.91       114

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(test_expected,test_pred))
print(accuracy_score(train_expected,train_pred))
# Out:
# 0.9122807017543859
# 1.0

# %% [markdown]
# # Decision Tree with 90% Data in Training
# 1. Above Data is baised as well as overfitted , (baised on both sides) , we'll be doing resampling in this section passing more
#    Data to training phase

# %%
X_train,X_test ,y_train,y_test = train_test_split(X,y, test_size = 0.1 , random_state = 0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (512, 30)
# (512, 1)
# (57, 30)
# (57, 1)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
train_expected = y_train
test_expected = y_test
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# %%
#Confusion Matrix
print(metrics.confusion_matrix(test_expected, test_pred),"\n-------------------------------")
print(metrics.confusion_matrix(train_expected, train_pred))
# Out:
# [[34  2]
#  [ 3 18]]
# -------------------------------
# [[321   0]
#  [  0 191]]

# %%
print(y_train['diagnosis'].value_counts())
print(y_test['diagnosis'].value_counts())
# Out:
# B    321
# M    191
# Name: diagnosis, dtype: int64
# B    36
# M    21
# Name: diagnosis, dtype: int64

# %%
print(metrics.classification_report(test_expected, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.92      0.94      0.93        36
#            M       0.90      0.86      0.88        21
#
#     accuracy                           0.91        57
#    macro avg       0.91      0.90      0.90        57
# weighted avg       0.91      0.91      0.91        57

# %%
print(accuracy_score(test_expected,test_pred))
print(accuracy_score(train_expected,train_pred))
# Out:
# 0.9122807017543859
# 1.0

# %% [markdown]
# # Decision Tree with hyperparamters
# 1. Model is still not performing well we'll be now tweeking the hyperparameters ,bcz it is not baised the only thing is different train,test samples .

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_train,X_test ,y_train,y_test = train_test_split(X,y, test_size = 0.1 , random_state = 0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (512, 30)
# (512, 1)
# (57, 30)
# (57, 1)

# %%
model = DecisionTreeClassifier(criterion='gini',max_depth=8, class_weight={'M':1, 'B':3})
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={'B': 3, 'M': 1}, max_depth=8)

# %%
train_expected = y_train
test_expected = y_test
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# %%
#Confusion Matrix
print(metrics.confusion_matrix(test_expected, test_pred),"\n-------------------------------")
print(metrics.confusion_matrix(train_expected, train_pred))
# Out:
# [[35  1]
#  [ 2 19]]
# -------------------------------
# [[321   0]
#  [  0 191]]

# %%
print(y_train['diagnosis'].value_counts())
print(y_test['diagnosis'].value_counts())
# Out:
# B    321
# M    191
# Name: diagnosis, dtype: int64
# B    36
# M    21
# Name: diagnosis, dtype: int64

# %%
print(metrics.classification_report(test_expected, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.97      0.96        36
#            M       0.95      0.90      0.93        21
#
#     accuracy                           0.95        57
#    macro avg       0.95      0.94      0.94        57
# weighted avg       0.95      0.95      0.95        57

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(test_expected,test_pred))
print(accuracy_score(train_expected,train_pred))
# Out:
# 0.9473684210526315
# 1.0

# %%
from sklearn.model_selection import cross_val_score 
accuracies = cross_val_score(estimator = model, X = X_train,\
     y = y_train, cv = 10)
print("Accuracy Mean {} Accuracy Variance \
     {}".format(accuracies.mean(),accuracies.std()))
print(accuracies)
# Out:
# Accuracy Mean 0.9354072398190045 Accuracy Variance      0.027929979050195574
# [0.98076923 0.96153846 0.92156863 0.88235294 0.94117647 0.94117647
#  0.90196078 0.92156863 0.96078431 0.94117647]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(24,14))
from sklearn import tree
tree.plot_tree(model, filled=True, fontsize=14)
# Out:
# [Text(1020.4961538461539, 718.76, 'X[22] <= 117.45\ngini = 0.276\nsamples = 512\nvalue = [963, 191]'),
#  Text(804.8076923076924, 634.1999999999999, 'X[27] <= 0.16\ngini = 0.075\nsamples = 358\nvalue = [957, 39]'),
#  Text(630.9692307692308, 549.64, 'X[23] <= 874.85\ngini = 0.04\nsamples = 338\nvalue = [954, 20]'),
#  Text(437.81538461538463, 465.0799999999999, 'X[27] <= 0.132\ngini = 0.025\nsamples = 324\nvalue = [936, 12]'),
#  Text(206.03076923076924, 380.52, 'X[18] <= 0.009\ngini = 0.007\nsamples = 295\nvalue = [876, 3]'),
#  Text(154.52307692307693, 295.9599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(257.53846153846155, 295.9599999999999, 'X[10] <= 0.643\ngini = 0.005\nsamples = 294\nvalue = [876, 2]'),
#  Text(154.52307692307693, 211.39999999999998, 'X[14] <= 0.003\ngini = 0.002\nsamples = 290\nvalue = [867, 1]'),
#  Text(103.01538461538462, 126.83999999999992, 'X[21] <= 26.89\ngini = 0.117\nsamples = 6\nvalue = [15, 1]'),
#  Text(51.50769230769231, 42.27999999999997, 'gini = 0.0\nsamples = 5\nvalue = [15, 0]'),
#  Text(154.52307692307693, 42.27999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(206.03076923076924, 126.83999999999992, 'gini = 0.0\nsamples = 284\nvalue = [852, 0]'),
#  Text(360.55384615384617, 211.39999999999998, 'X[25] <= 0.085\ngini = 0.18\nsamples = 4\nvalue = [9, 1]'),
#  Text(309.04615384615386, 126.83999999999992, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(412.0615384615385, 126.83999999999992, 'gini = 0.0\nsamples = 3\nvalue = [9, 0]'),
#  Text(669.6, 380.52, 'X[1] <= 21.125\ngini = 0.227\nsamples = 29\nvalue = [60, 9]'),
#  Text(618.0923076923077, 295.9599999999999, 'X[21] <= 29.06\ngini = 0.091\nsamples = 23\nvalue = [60, 3]'),
#  Text(566.5846153846154, 211.39999999999998, 'X[23] <= 811.1\ngini = 0.062\nsamples = 22\nvalue = [60, 2]'),
#  Text(515.0769230769231, 126.83999999999992, 'gini = 0.0\nsamples = 17\nvalue = [51, 0]'),
#  Text(618.0923076923077, 126.83999999999992, 'X[3] <= 610.4\ngini = 0.298\nsamples = 5\nvalue = [9, 2]'),
#  Text(566.5846153846154, 42.27999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(669.6, 42.27999999999997, 'gini = 0.0\nsamples = 3\nvalue = [9, 0]'),
#  Text(669.6, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(721.1076923076923, 295.9599999999999, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(824.123076923077, 465.0799999999999, 'X[1] <= 18.835\ngini = 0.426\nsamples = 14\nvalue = [18, 8]'),
#  Text(772.6153846153846, 380.52, 'gini = 0.0\nsamples = 6\nvalue = [18, 0]'),
#  Text(875.6307692307693, 380.52, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(978.6461538461539, 549.64, 'X[13] <= 13.475\ngini = 0.236\nsamples = 20\nvalue = [3, 19]'),
#  Text(927.1384615384616, 465.0799999999999, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(1030.1538461538462, 465.0799999999999, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(1236.1846153846154, 634.1999999999999, 'X[24] <= 0.1\ngini = 0.073\nsamples = 154\nvalue = [6, 152]'),
#  Text(1184.6769230769232, 549.64, 'X[12] <= 3.895\ngini = 0.245\nsamples = 3\nvalue = [6, 1]'),
#  Text(1133.1692307692308, 465.0799999999999, 'gini = 0.0\nsamples = 2\nvalue = [6, 0]'),
#  Text(1236.1846153846154, 465.0799999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1287.6923076923076, 549.64, 'gini = 0.0\nsamples = 151\nvalue = [0, 151]')]

# %%
print(X_train.columns[22])
X_train[X_train.columns[22]].shape
# Out:
# perimeter_worst
# (512,)

# %%
pd.concat([X_train,y_train], axis=1).groupby(by='diagnosis', as_index=False).aggregate({'perimeter_worst':'count'})
# Out:
#   diagnosis  perimeter_worst
# 0         B              321
# 1         M              191

# %% [markdown]
# # Decision Tree with hyperparameters

# %%
import sklearn 
from sklearn.model_selection import train_test_split

# %%
X_train,X_test ,y_train,y_test = train_test_split(X,y, test_size = 0.1 , random_state = 0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (512, 30)
# (512, 1)
# (57, 30)
# (57, 1)

# %%
model = DecisionTreeClassifier(criterion='gini', min_impurity_decrease=0.001, class_weight={'M':1, 'B':2})
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={'B': 2, 'M': 1},
#                        min_impurity_decrease=0.001)

# %%
train_expected = y_train
test_expected = y_test
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# %%
#Confusion Matrix
print(metrics.confusion_matrix(test_expected, test_pred),"\n-------------------------------")
print(metrics.confusion_matrix(train_expected, train_pred))
# Out:
# [[35  1]
#  [ 4 17]]
# -------------------------------
# [[321   0]
#  [  3 188]]

# %%
print(y_train['diagnosis'].value_counts())
print(y_test['diagnosis'].value_counts())
# Out:
# B    321
# M    191
# Name: diagnosis, dtype: int64
# B    36
# M    21
# Name: diagnosis, dtype: int64

# %%
print(metrics.classification_report(test_expected, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.90      0.97      0.93        36
#            M       0.94      0.81      0.87        21
#
#     accuracy                           0.91        57
#    macro avg       0.92      0.89      0.90        57
# weighted avg       0.91      0.91      0.91        57

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(test_expected,test_pred))
print(accuracy_score(train_expected,train_pred))
# Out:
# 0.9122807017543859
# 0.994140625

# %%
from sklearn.model_selection import cross_val_score 
accuracies = cross_val_score(estimator = model, X = X_train,\
     y = y_train, cv = 10)
print("Accuracy Mean {} Accuracy Variance \
     {}".format(accuracies.mean(),accuracies.std()))
print(accuracies)
# Out:
# Accuracy Mean 0.9471719457013574 Accuracy Variance      0.02788228885118536
# [0.96153846 0.98076923 0.94117647 0.88235294 0.96078431 0.94117647
#  0.98039216 0.94117647 0.96078431 0.92156863]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(24,14))
from sklearn import tree
tree.plot_tree(model, filled=True, fontsize=14)
# Out:
# [Text(902.1, 706.68, 'X[22] <= 117.45\ngini = 0.353\nsamples = 512\nvalue = [642, 191]'),
#  Text(613.8000000000001, 597.96, 'X[27] <= 0.16\ngini = 0.109\nsamples = 358\nvalue = [638, 39]'),
#  Text(409.20000000000005, 489.23999999999995, 'X[22] <= 107.45\ngini = 0.059\nsamples = 338\nvalue = [636, 20]'),
#  Text(223.20000000000002, 380.52, 'X[13] <= 91.555\ngini = 0.02\nsamples = 303\nvalue = [594, 6]'),
#  Text(148.8, 271.79999999999995, 'X[24] <= 0.178\ngini = 0.017\nsamples = 302\nvalue = [594, 5]'),
#  Text(74.4, 163.07999999999993, 'gini = 0.01\nsamples = 297\nvalue = [588, 3]'),
#  Text(223.20000000000002, 163.07999999999993, 'X[24] <= 0.182\ngini = 0.375\nsamples = 5\nvalue = [6, 2]'),
#  Text(148.8, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(297.6, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]'),
#  Text(297.6, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(595.2, 380.52, 'X[1] <= 19.36\ngini = 0.375\nsamples = 35\nvalue = [42, 14]'),
#  Text(446.40000000000003, 271.79999999999995, 'X[2] <= 91.97\ngini = 0.105\nsamples = 19\nvalue = [34, 2]'),
#  Text(372.0, 163.07999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(520.8000000000001, 163.07999999999993, 'gini = 0.0\nsamples = 17\nvalue = [34, 0]'),
#  Text(744.0, 271.79999999999995, 'X[25] <= 0.332\ngini = 0.48\nsamples = 16\nvalue = [8, 12]'),
#  Text(669.6, 163.07999999999993, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(818.4000000000001, 163.07999999999993, 'X[24] <= 0.139\ngini = 0.32\nsamples = 6\nvalue = [8, 2]'),
#  Text(744.0, 54.360000000000014, 'gini = 0.0\nsamples = 4\nvalue = [8, 0]'),
#  Text(892.8000000000001, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(818.4000000000001, 489.23999999999995, 'X[13] <= 13.475\ngini = 0.172\nsamples = 20\nvalue = [2, 19]'),
#  Text(744.0, 380.52, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(892.8000000000001, 380.52, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(1190.4, 597.96, 'X[19] <= 0.002\ngini = 0.05\nsamples = 154\nvalue = [4, 152]'),
#  Text(1116.0, 489.23999999999995, 'X[26] <= 0.271\ngini = 0.32\nsamples = 3\nvalue = [4, 1]'),
#  Text(1041.6000000000001, 380.52, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(1190.4, 380.52, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1264.8000000000002, 489.23999999999995, 'gini = 0.0\nsamples = 151\nvalue = [0, 151]')]
